# %%
# Out:
# Invalid drive specification.
# curl: (3) URL rejected: Port number was not a decimal number between 0 and 65535
# 'filters%5Bstate.keyword%5D' is not recognized as an internal or external command,
# operable program or batch file.
# 'filters%5Bcommodity%5D' is not recognized as an internal or external command,
# operable program or batch file.
