# %%
import pandas as pd

df = pd.read_csv("Agriculture_price_dataset.csv")

# %%
# Keep only rows where state = Maharashtra
df = df[df['STATE'] == 'Maharashtra']

df.to_csv("filtered.csv", index=False)

# %%
unique_pairs = df[['District Name','Market Name']].drop_duplicates()

for i in unique_pairs.iterrows():
    if "Market" in i[1][1] or "Bazar" in i[1][1]:
        print(i[1][1])
# Out:
# Chandur Bazar
# Amrawati(Frui & Veg. Market)
# Sangli(Phale, Bhajipura Market)
# Varud(Rajura Bazar)
# Laxmi Sopan Agriculture Produce Marketing Co Ltd
# Shree Salasar Krushi Bazar
# Shree Rameshwar Krushi Market
# Shree Sairaj Krushi Market
# Janata Agri Market (DLS Agro Infrastructure Pvt Lt
# Sant Namdev Krushi Bazar,
# Premium Krushi Utpanna Bazar
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_21468\2051475019.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if "Market" in i[1][1] or "Bazar" in i[1][1]:
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_21468\2051475019.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(i[1][1])

# %%
df["District Name"] = df["District Name"].str.lower()
df["Market Name"] = df["Market Name"].str.lower()

# %%
df2 =  pd.read_csv("cities.csv")
df2["city"] = df2["city"].str.lower()
df2["district"] = df2["district"].str.lower()
df2 = df2.drop_duplicates(subset=["district"])
df2["district"] = df2["district"].replace("amravati", "amarawati")
merged = df.merge(df2, left_on="District Name", right_on="district", how="left")


print(merged)
# Out:
#              STATE District Name                             Market Name  \
# 0      Maharashtra        nashik                       lasalgaon(niphad)
# 1      Maharashtra        satara                                   patan
# 2      Maharashtra        nashik                      lasalgaon(vinchur)
# 3      Maharashtra    ahmednagar                                pathardi
# 4      Maharashtra         dhule  pratap nana mahale khajgi bajar samiti
# ...            ...           ...                                     ...
# 51811  Maharashtra          pune                            khed(chakan)
# 51812  Maharashtra    chandrapur                     chandrapur(ganjwad)
# 51813  Maharashtra          pune                           pune(khadiki)
# 51814  Maharashtra       jalgaon                                bhusaval
# 51815  Maharashtra        nashik                              pimpalgaon
#
#       Commodity           Variety  Grade  Min_Price  Max_Price  Modal_Price  \
# 0         Wheat  Maharashtra 2189    FAQ     2172.0     2399.0      2300.00
# 1        Tomato             Other    FAQ     1000.0     1500.0      1250.00
# 2         Wheat             Other    FAQ     2100.0     2382.0      2200.00
# 3         Onion               Red    FAQ      200.0      900.0       600.00
# 4         Onion               Red    FAQ      300.0      750.0       461.93
# ...         ...               ...    ...        ...        ...          ...
# 51811    Potato             Other  Local     1500.0     2200.0      1800.00
# 51812     Onion             Other  Local     1400.0     1800.0      1600.00
# 51813    Potato             Local  Local     1200.0     1500.0      1350.00
# 51814     Onion             Other  Local     1000.0     1500.0      1200.00
# 51815     Onion             Other  Local      540.0     2476.0      1550.00
#
#       Price Date  ...    district std-code        state  gst-state-code  \
# 0       6/6/2023  ...      nashik    253.0  Maharashtra              MH
# 1       6/6/2023  ...      satara   2162.0  Maharashtra              MH
# 2       6/6/2023  ...      nashik    253.0  Maharashtra              MH
# 3       6/6/2023  ...  ahmednagar    241.0  Maharashtra              MH
# 4       6/6/2023  ...       dhule   2562.0  Maharashtra              MH
# ...          ...  ...         ...      ...          ...             ...
# 51811  6/11/2025  ...        pune    212.0  Maharashtra              MH
# 51812  6/11/2025  ...  chandrapur   7172.0  Maharashtra              MH
# 51813  6/11/2025  ...        pune    212.0  Maharashtra              MH
# 51814  6/11/2025  ...     jalgaon   2587.0  Maharashtra              MH
# 51815  6/11/2025  ...      nashik    253.0  Maharashtra              MH
#
#       iso_3166-2 population   rank   latitude  longitude    altitude
# 0          IN-MH  1817359.0   20.0  19.997453  73.789802  582.673645
# 1          IN-MH   149335.0  298.0  17.680464  74.018261  689.331726
# 2          IN-MH  1817359.0   20.0  19.997453  73.789802  582.673645
# 3          IN-MH   350000.0  126.0  19.095208  74.749592  657.411499
# 4          IN-MH   380000.0  115.0  20.904220  74.774898  263.158325
# ...          ...        ...    ...        ...        ...         ...
# 51811      IN-MH  1772891.0   21.0  18.623540  73.807873  572.507690
# 51812      IN-MH   325000.0  136.0  19.970460  79.301485  205.014160
# 51813      IN-MH  1772891.0   21.0  18.623540  73.807873  572.507690
# 51814      IN-MH    96000.0  484.0  21.041921  75.058194  189.418259
# 51815      IN-MH  1817359.0   20.0  19.997453  73.789802  582.673645
#
# [51816 rows x 22 columns]

# %%
merged = merged.dropna(subset=["city"])
merged.to_csv("joined.csv", index=False)

# %%
test = merged.copy()
test["Price Date"] = pd.to_datetime(test["Price Date"], errors="coerce")
test.to_csv("date.csv",  index = True)

# %%
for i, roes in unique_pairs.iterrows():
    print(i, roes)
# Out:
# 0 District Name               nashik
# Market Name      Lasalgaon(Niphad)
# lat                       9.904997
# lon                       78.10483
# Name: 0, dtype: object
# 1 District Name       satara
# Market Name          Patan
# lat              18.906836
# lon              75.674158
# Name: 1, dtype: object
# 19 District Name                nashik
# Market Name      Lasalgaon(Vinchur)
# lat                        9.904997
# lon                        78.10483
# Name: 19, dtype: object
# 39 District Name    ahmednagar
# Market Name        Pathardi
# lat               18.906836
# lon               75.674158
# Name: 39, dtype: object
# 41 District Name                                     dhule
# Market Name      Pratap Nana Mahale Khajgi Bajar Samiti
# lat                                           18.906836
# lon                                           75.674158
# Name: 41, dtype: object
# 42 District Name       satara
# Market Name        Phaltan
# lat              18.906836
# lon              75.674158
# Name: 42, dtype: object
# 44 District Name    ahmednagar
# Market Name      Shrirampur
# lat               20.391683
# lon               77.215982
# Name: 44, dtype: object
# 59 District Name        nashik
# Market Name      Pimpalgaon
# lat               18.906836
# lon               75.674158
# Name: 59, dtype: object
# 82 District Name              mumbai
# Market Name      Vashi New Mumbai
# lat                     19.363427
# lon                     76.312049
# Name: 82, dtype: object
# 98 District Name       nashik
# Market Name       Malegaon
# lat              19.055997
# lon              72.922665
# Name: 98, dtype: object
# 115 District Name     kolhapur
# Market Name       Kolhapur
# lat              17.456168
# lon              78.535967
# Name: 115, dtype: object
# 127 District Name       nashik
# Market Name       Nandgaon
# lat              19.027994
# lon              72.836582
# Name: 127, dtype: object
# 179 District Name                          nashik
# Market Name      Pimpalgaon Baswant(Saykheda)
# lat                                 18.906836
# lon                                 75.674158
# Name: 179, dtype: object
# 217 District Name         pune
# Market Name        Manchar
# lat              19.055997
# lon              72.922665
# Name: 217, dtype: object
# 224 District Name    ahmednagar
# Market Name          Rahuri
# lat                19.21482
# lon               72.842627
# Name: 224, dtype: object
# 237 District Name            pune
# Market Name      Khed(Chakan)
# lat                 17.456168
# lon                 78.535967
# Name: 237, dtype: object
# 246 District Name    ahmednagar
# Market Name       Sangamner
# lat               20.391683
# lon               77.215982
# Name: 246, dtype: object
# 250 District Name       sangli
# Market Name         Sangli
# lat              20.391683
# lon              77.215982
# Name: 250, dtype: object
# 267 District Name      jalgaon
# Market Name          Yawal
# lat              20.097016
# lon              73.014167
# Name: 267, dtype: object
# 269 District Name       nashik
# Market Name         Satana
# lat              20.391683
# lon              77.215982
# Name: 269, dtype: object
# 278 District Name            pune
# Market Name      Pune(Pimpri)
# lat                 18.906836
# lon                 75.674158
# Name: 278, dtype: object
# 289 District Name     sholapur
# Market Name        Solapur
# lat              20.391683
# lon              77.215982
# Name: 289, dtype: object
# 299 District Name       satara
# Market Name            Vai
# lat              19.363427
# lon              76.312049
# Name: 299, dtype: object
# 303 District Name    ahmednagar
# Market Name          Rahata
# lat                19.21482
# lon               72.842627
# Name: 303, dtype: object
# 312 District Name       raigad
# Market Name         Panvel
# lat              18.906836
# lon              75.674158
# Name: 312, dtype: object
# 334 District Name       nanded
# Market Name         Nanded
# lat              19.027994
# lon              72.836582
# Name: 334, dtype: object
# 337 District Name             pune
# Market Name      Pune(Khadiki)
# lat                  18.906836
# lon                  75.674158
# Name: 337, dtype: object
# 354 District Name            pune
# Market Name      Pune(Manjri)
# lat                 18.906836
# lon                 75.674158
# Name: 354, dtype: object
# 374 District Name        amarawati
# Market Name      Chandur Bazar
# lat                  17.128285
# lon                  78.459436
# Name: 374, dtype: object
# 385 District Name         pune
# Market Name           Pune
# lat              18.906836
# lon              75.674158
# Name: 385, dtype: object
# 391 District Name       nashik
# Market Name      Lasalgaon
# lat               9.904997
# lon               78.10483
# Name: 391, dtype: object
# 393 District Name      jalgaon
# Market Name         Parola
# lat              18.906836
# lon              75.674158
# Name: 393, dtype: object
# 419 District Name                       amarawati
# Market Name      Amrawati(Frui & Veg. Market)
# lat                                 12.655489
# lon                                 77.212809
# Name: 419, dtype: object
# 424 District Name    amarawati
# Market Name      Amarawati
# lat              12.655489
# lon              77.212809
# Name: 424, dtype: object
# 439 District Name                pune
# Market Name      Junnar(Alephata)
# lat                     18.961953
# lon                     72.832585
# Name: 439, dtype: object
# 445 District Name        akola
# Market Name          Akola
# lat              12.655489
# lon              77.212809
# Name: 445, dtype: object
# 489 District Name     sholapur
# Market Name         Barshi
# lat              19.405779
# lon               75.70204
# Name: 489, dtype: object
# 496 District Name       mumbai
# Market Name         Mumbai
# lat              19.055997
# lon              72.922665
# Name: 496, dtype: object
# 505 District Name       satara
# Market Name         Satara
# lat              20.391683
# lon              77.215982
# Name: 505, dtype: object
# 511 District Name       sangli
# Market Name       Islampur
# lat              18.733232
# lon              79.331818
# Name: 511, dtype: object
# 517 District Name      hingoli
# Market Name        Hingoli
# lat              18.980586
# lon              73.120856
# Name: 517, dtype: object
# 530 District Name        wardha
# Market Name      Hinganghat
# lat               18.980586
# lon               73.120856
# Name: 530, dtype: object
# 542 District Name       satara
# Market Name          Karad
# lat              17.456168
# lon              78.535967
# Name: 542, dtype: object
# 552 District Name            raigad
# Market Name      Karjat(Raigad)
# lat                   17.456168
# lon                   78.535967
# Name: 552, dtype: object
# 595 District Name    ahmednagar
# Market Name        Shevgaon
# lat               20.391683
# lon               77.215982
# Name: 595, dtype: object
# 601 District Name         ahmednagar
# Market Name      Rahuri(Vambori)
# lat                     19.21482
# lon                    72.842627
# Name: 601, dtype: object
# 644 District Name        dhule
# Market Name      Dondaicha
# lat              28.660704
# lon              77.006429
# Name: 644, dtype: object
# 681 District Name    ahmednagar
# Market Name         Jamkhed
# lat               18.961953
# lon               72.832585
# Name: 681, dtype: object
# 689 District Name          sholapur
# Market Name      Barshi(Vairag)
# lat                   19.405779
# lon                    75.70204
# Name: 689, dtype: object
# 702 District Name     parbhani
# Market Name       Parbhani
# lat              18.906836
# lon              75.674158
# Name: 702, dtype: object
# 703 District Name       nashik
# Market Name         Kalvan
# lat              17.456168
# lon              78.535967
# Name: 703, dtype: object
# 705 District Name     sholapur
# Market Name        Karmala
# lat              17.456168
# lon              78.535967
# Name: 705, dtype: object
# 710 District Name         beed
# Market Name      Majalgaon
# lat              19.055997
# lon              72.922665
# Name: 710, dtype: object
# 727 District Name       wardha
# Market Name         Wardha
# lat              19.067019
# lon              72.895504
# Name: 727, dtype: object
# 771 District Name       nagpur
# Market Name         Nagpur
# lat              19.027994
# lon              72.836582
# Name: 771, dtype: object
# 776 District Name     parbhani
# Market Name      Gangakhed
# lat              13.021404
# lon              77.764452
# Name: 776, dtype: object
# 789 District Name      sholapur
# Market Name      Pandharpur
# lat               18.906836
# lon               75.674158
# Name: 789, dtype: object
# 832 District Name         thane
# Market Name      Ulhasnagar
# lat               19.197312
# lon               72.946178
# Name: 832, dtype: object
# 846 District Name      jalgaon
# Market Name          Raver
# lat               19.21482
# lon              72.842627
# Name: 846, dtype: object
# 901 District Name        dhule
# Market Name        Shirpur
# lat              20.391683
# lon              77.215982
# Name: 901, dtype: object
# 904 District Name       nashik
# Market Name         Manmad
# lat              19.055997
# lon              72.922665
# Name: 904, dtype: object
# 931 District Name     sholapur
# Market Name        Dudhani
# lat              28.660704
# lon              77.006429
# Name: 931, dtype: object
# 936 District Name      jalgaon
# Market Name        Chopada
# lat              17.128285
# lon              78.459436
# Name: 936, dtype: object
# 956 District Name            amarawati
# Market Name      Dhamngaon-Railway
# lat                      28.660704
# lon                      77.006429
# Name: 956, dtype: object
# 963 District Name             ahmednagar
# Market Name      Shevgaon(Bodhegaon)
# lat                        20.391683
# lon                        77.215982
# Name: 963, dtype: object
# 968 District Name    nandurbar
# Market Name        Shahada
# lat              20.391683
# lon              77.215982
# Name: 968, dtype: object
# 974 District Name            beed
# Market Name      Kille Dharur
# lat                 17.456168
# lon                 78.535967
# Name: 974, dtype: object
# 978 District Name      jalgaon
# Market Name       Bhusaval
# lat              19.405779
# lon               75.70204
# Name: 978, dtype: object
# 1001 District Name       sangli
# Market Name        Tasgaon
# lat              19.405779
# lon               75.70204
# Name: 1001, dtype: object
# 1021 District Name       nagpur
# Market Name         Savner
# lat              20.391683
# lon              77.215982
# Name: 1021, dtype: object
# 1026 District Name           pune
# Market Name      Pune(Moshi)
# lat                18.906836
# lon                75.674158
# Name: 1026, dtype: object
# 1080 District Name           nashik
# Market Name      Dindori(Vani)
# lat                  28.660704
# lon                  77.006429
# Name: 1080, dtype: object
# 1091 District Name    nandurbar
# Market Name      Nandurbar
# lat              19.027994
# lon              72.836582
# Name: 1091, dtype: object
# 1114 District Name        thane
# Market Name        Palghar
# lat              18.906836
# lon              75.674158
# Name: 1114, dtype: object
# 1144 District Name                   pune
# Market Name      Junnar(Narayangaon)
# lat                        18.961953
# lon                        72.832585
# Name: 1144, dtype: object
# 1149 District Name       nagpur
# Market Name         Ramtek
# lat               19.21482
# lon              72.842627
# Name: 1149, dtype: object
# 1154 District Name      jalgaon
# Market Name        Jalgaon
# lat              18.961953
# lon              72.832585
# Name: 1154, dtype: object
# 1157 District Name       nashik
# Market Name          Ghoti
# lat              13.021404
# lon              77.764452
# Name: 1157, dtype: object
# 1177 District Name       nanded
# Market Name         Bhokar
# lat              19.405779
# lon               75.70204
# Name: 1177, dtype: object
# 1205 District Name         beed
# Market Name         Gevrai
# lat              13.021404
# lon              77.764452
# Name: 1205, dtype: object
# 1216 District Name       nashik
# Market Name          Nasik
# lat              19.027994
# lon              72.836582
# Name: 1216, dtype: object
# 1269 District Name       nagpur
# Market Name         Kamthi
# lat              17.456168
# lon              78.535967
# Name: 1269, dtype: object
# 1315 District Name       nagpur
# Market Name          Katol
# lat              17.456168
# lon              78.535967
# Name: 1315, dtype: object
# 1373 District Name       nashik
# Market Name         Devala
# lat              28.660704
# lon              77.006429
# Name: 1373, dtype: object
# 1405 District Name    ahmednagar
# Market Name      Ahmednagar
# lat               12.655489
# lon               77.212809
# Name: 1405, dtype: object
# 1430 District Name            wardha
# Market Name      Ashti(Karanja)
# lat                   12.655489
# lon                   77.212809
# Name: 1430, dtype: object
# 1444 District Name       raigad
# Market Name            Pen
# lat              18.906836
# lon              75.674158
# Name: 1444, dtype: object
# 1468 District Name      jalgaon
# Market Name        Amalner
# lat              12.655489
# lon              77.212809
# Name: 1468, dtype: object
# 1488 District Name    amarawati
# Market Name       Achalpur
# lat              12.655489
# lon              77.212809
# Name: 1488, dtype: object
# 1499 District Name        nagpur
# Market Name      Kalmeshwar
# lat               17.456168
# lon               78.535967
# Name: 1499, dtype: object
# 1601 District Name    amarawati
# Market Name      Anajngaon
# lat              12.655489
# lon              77.212809
# Name: 1601, dtype: object
# 1608 District Name    nandurbar
# Market Name        Navapur
# lat              19.027994
# lon              72.836582
# Name: 1608, dtype: object
# 1642 District Name         beed
# Market Name           Beed
# lat              19.405779
# lon               75.70204
# Name: 1642, dtype: object
# 1703 District Name              latur
# Market Name      Aurad Shahajani
# lat                    12.655489
# lon                    77.212809
# Name: 1703, dtype: object
# 1706 District Name       nashik
# Market Name       Chandvad
# lat              17.128285
# lon              78.459436
# Name: 1706, dtype: object
# 1710 District Name    ahmednagar
# Market Name           Akole
# lat               12.655489
# lon               77.212809
# Name: 1710, dtype: object
# 1756 District Name                             sangli
# Market Name      Sangli(Phale, Bhajipura Market)
# lat                                    20.391683
# lon                                    77.215982
# Name: 1756, dtype: object
# 1770 District Name        latur
# Market Name       Ahmedpur
# lat              12.655489
# lon              77.212809
# Name: 1770, dtype: object
# 1779 District Name       nashik
# Market Name         Sinner
# lat              20.391683
# lon              77.215982
# Name: 1779, dtype: object
# 1794 District Name             chandrapur
# Market Name      Chandrapur(Ganjwad)
# lat                        17.128285
# lon                        78.459436
# Name: 1794, dtype: object
# 1798 District Name       nashik
# Market Name        Dindori
# lat              28.660704
# lon              77.006429
# Name: 1798, dtype: object
# 1810 District Name        dhule
# Market Name          Dhule
# lat              28.660704
# lon              77.006429
# Name: 1810, dtype: object
# 1861 District Name            pune
# Market Name      Junnar(Otur)
# lat                 18.961953
# lon                 72.832585
# Name: 1861, dtype: object
# 1902 District Name    ahmednagar
# Market Name       Shrigonda
# lat               20.391683
# lon               77.215982
# Name: 1902, dtype: object
# 1904 District Name    ahmednagar
# Market Name          Parner
# lat               18.906836
# lon               75.674158
# Name: 1904, dtype: object
# 2009 District Name       nashik
# Market Name          Yeola
# lat              20.097016
# lon              73.014167
# Name: 2009, dtype: object
# 2032 District Name    aurangabad
# Market Name            Amba
# lat               12.655489
# lon               77.212809
# Name: 2032, dtype: object
# 2063 District Name         beed
# Market Name           Kaij
# lat              17.456168
# lon              78.535967
# Name: 2063, dtype: object
# 2264 District Name         akola
# Market Name      Murtizapur
# lat               19.055997
# lon               72.922665
# Name: 2264, dtype: object
# 2335 District Name             ahmednagar
# Market Name      Shrirampur(Belapur)
# lat                        20.391683
# lon                        77.215982
# Name: 2335, dtype: object
# 2457 District Name     bhandara
# Market Name         Tumsar
# lat              19.405779
# lon               75.70204
# Name: 2457, dtype: object
# 2479 District Name         wardha
# Market Name      Sindi(Selu)
# lat                20.391683
# lon                77.215982
# Name: 2479, dtype: object
# 2509 District Name     sholapur
# Market Name          Akluj
# lat              12.655489
# lon              77.212809
# Name: 2509, dtype: object
# 2547 District Name        thane
# Market Name          Vasai
# lat              19.363427
# lon              76.312049
# Name: 2547, dtype: object
# 2558 District Name       jalgaon
# Market Name      Dharangaon
# lat               28.660704
# lon               77.006429
# Name: 2558, dtype: object
# 2567 District Name    ahmednagar
# Market Name       Kopargaon
# lat               17.456168
# lon               78.535967
# Name: 2567, dtype: object
# 2607 District Name       kolhapur
# Market Name      Vadgaonpeth
# lat                19.363427
# lon                76.312049
# Name: 2607, dtype: object
# 2871 District Name           ahmednagar
# Market Name      Newasa(Ghodegaon)
# lat                      19.027994
# lon                      72.836582
# Name: 2871, dtype: object
# 2881 District Name              ratnagiri
# Market Name      Ratnagiri (Nachane)
# lat                         19.21482
# lon                        72.842627
# Name: 2881, dtype: object
# 2898 District Name      nanded
# Market Name          Loha
# lat              9.904997
# lon              78.10483
# Name: 2898, dtype: object
# 2911 District Name       nagpur
# Market Name         Hingna
# lat              18.980586
# lon              73.120856
# Name: 2911, dtype: object
# 2956 District Name         pune
# Market Name       Baramati
# lat              19.405779
# lon               75.70204
# Name: 2956, dtype: object
# 2994 District Name            pune
# Market Name      Nira(Saswad)
# lat                 19.027994
# lon                 72.836582
# Name: 2994, dtype: object
# 3396 District Name        sholapur
# Market Name      Mangal Wedha
# lat                 19.055997
# lon                 72.922665
# Name: 3396, dtype: object
# 3620 District Name       nanded
# Market Name        Kandhar
# lat              17.456168
# lon              78.535967
# Name: 3620, dtype: object
# 3689 District Name       wardha
# Market Name        Pulgaon
# lat              18.906836
# lon              75.674158
# Name: 3689, dtype: object
# 3725 District Name         pune
# Market Name         Junnar
# lat              18.961953
# lon              72.832585
# Name: 3725, dtype: object
# 3780 District Name         pune
# Market Name          Dound
# lat              28.660704
# lon              77.006429
# Name: 3780, dtype: object
# 3834 District Name    amarawati
# Market Name         Morshi
# lat              19.055997
# lon              72.922665
# Name: 3834, dtype: object
# 3918 District Name     parbhani
# Market Name       Tadkalas
# lat              19.405779
# lon               75.70204
# Name: 3918, dtype: object
# 4007 District Name       nagpur
# Market Name         Umared
# lat              19.197312
# lon              72.946178
# Name: 4007, dtype: object
# 4205 District Name             sholapur
# Market Name      Kurdwadi(Modnimb)
# lat                      17.456168
# lon                      78.535967
# Name: 4205, dtype: object
# 4343 District Name      satara
# Market Name        Lonand
# lat              9.904997
# lon              78.10483
# Name: 4343, dtype: object
# 4352 District Name     bhandara
# Market Name       Bhandara
# lat              19.405779
# lon               75.70204
# Name: 4352, dtype: object
# 4658 District Name        latur
# Market Name         Chakur
# lat              17.128285
# lon              78.459436
# Name: 4658, dtype: object
# 4662 District Name        latur
# Market Name           Ausa
# lat              12.655489
# lon              77.212809
# Name: 4662, dtype: object
# 4687 District Name                                               nashik
# Market Name      Mankamneshwar Farmar Producer CoLtd Sanchalit ...
# lat                                                      19.055997
# lon                                                      72.922665
# Name: 4687, dtype: object
# 5387 District Name     parbhani
# Market Name        Pathari
# lat              18.906836
# lon              75.674158
# Name: 5387, dtype: object
# 6614 District Name      jalgaon
# Market Name        Pachora
# lat              18.906836
# lon              75.674158
# Name: 6614, dtype: object
# 6819 District Name        akola
# Market Name          Patur
# lat              18.906836
# lon              75.674158
# Name: 6819, dtype: object
# 7502 District Name       sangli
# Market Name          Palus
# lat              18.906836
# lon              75.674158
# Name: 7502, dtype: object
# 7543 District Name         beed
# Market Name           Kada
# lat              17.456168
# lon              78.535967
# Name: 7543, dtype: object
# 8619 District Name       satara
# Market Name          Vaduj
# lat              19.363427
# lon              76.312049
# Name: 8619, dtype: object
# 8778 District Name        akola
# Market Name        Telhara
# lat              19.405779
# lon               75.70204
# Name: 8778, dtype: object
# 9732 District Name        akola
# Market Name        Balapur
# lat              19.405779
# lon               75.70204
# Name: 9732, dtype: object
# 9967 District Name       nashik
# Market Name         Nampur
# lat              19.027994
# lon              72.836582
# Name: 9967, dtype: object
# 10087 District Name       nashik
# Market Name         Umrane
# lat              19.197312
# lon              72.946178
# Name: 10087, dtype: object
# 11038 District Name     parbhani
# Market Name        Sonpeth
# lat              20.391683
# lon              77.215982
# Name: 11038, dtype: object
# 11090 District Name     sholapur
# Market Name       Akkalkot
# lat              12.655489
# lon              77.212809
# Name: 11090, dtype: object
# 13473 District Name       jalgaon
# Market Name      Chalisgaon
# lat               17.128285
# lon               78.459436
# Name: 13473, dtype: object
# 13576 District Name               amarawati
# Market Name      Nandgaon Khandeshwar
# lat                         19.027994
# lon                         72.836582
# Name: 13576, dtype: object
# 13710 District Name    ahmednagar
# Market Name          Newasa
# lat               19.027994
# lon               72.836582
# Name: 13710, dtype: object
# 14780 District Name     parbhani
# Market Name         Manwat
# lat              19.055997
# lon              72.922665
# Name: 14780, dtype: object
# 15362 District Name         pune
# Market Name         Shirur
# lat              20.391683
# lon              77.215982
# Name: 15362, dtype: object
# 16353 District Name                    dhule
# Market Name      Dondaicha(Sindhkheda)
# lat                          28.660704
# lon                          77.006429
# Name: 16353, dtype: object
# 16763 District Name              amarawati
# Market Name      Varud(Rajura Bazar)
# lat                        19.363427
# lon                        76.312049
# Name: 16763, dtype: object
# 21709 District Name       nashik
# Market Name       Suragana
# lat              20.391683
# lon              77.215982
# Name: 21709, dtype: object
# 21823 District Name         pune
# Market Name        Indapur
# lat              18.733232
# lon              79.331818
# Name: 21823, dtype: object
# 22770 District Name        thane
# Market Name         Kalyan
# lat              17.456168
# lon              78.535967
# Name: 22770, dtype: object
# 24661 District Name     sholapur
# Market Name       Kurdwadi
# lat              17.456168
# lon              78.535967
# Name: 24661, dtype: object
# 26534 District Name        dhule
# Market Name          Sakri
# lat              20.391683
# lon              77.215982
# Name: 26534, dtype: object
# 28232 District Name    amarawati
# Market Name         Dharni
# lat              28.660704
# lon              77.006429
# Name: 28232, dtype: object
# 31106 District Name                      pune
# Market Name      Indapur(Nimgaon Ketki)
# lat                           18.733232
# lon                           79.331818
# Name: 31106, dtype: object
# 32001 District Name             jalgaon
# Market Name      Jalgaon(Masawat)
# lat                     18.961953
# lon                     72.832585
# Name: 32001, dtype: object
# 36461 District Name                   hingoli
# Market Name      Hingoli(Kanegoan Naka)
# lat                           18.980586
# lon                           73.120856
# Name: 36461, dtype: object
# 38781 District Name                                            sholapur
# Market Name      Laxmi Sopan Agriculture Produce Marketing Co Ltd
# lat                                                      9.904997
# lon                                                      78.10483
# Name: 38781, dtype: object
# 40457 District Name        thane
# Market Name         Murbad
# lat              19.055997
# lon              72.922665
# Name: 40457, dtype: object
# 42781 District Name       latur
# Market Name         Latur
# lat              9.904997
# lon              78.10483
# Name: 42781, dtype: object
# 44245 District Name                                 nashik
# Market Name      Malharshree Farmers Producer Co Ltd
# lat                                        19.055997
# lon                                        72.922665
# Name: 44245, dtype: object
# 45026 District Name                      parbhani
# Market Name      Shree Salasar Krushi Bazar
# lat                               20.391683
# lon                               77.215982
# Name: 45026, dtype: object
# 45533 District Name                           nashik
# Market Name      Shree Rameshwar Krushi Market
# lat                                  20.391683
# lon                                  77.215982
# Name: 45533, dtype: object
# 45651 District Name        nagpur
# Market Name      Parshiwani
# lat               18.906836
# lon               75.674158
# Name: 45651, dtype: object
# 46041 District Name          hingoli
# Market Name      Akhadabalapur
# lat                  12.655489
# lon                  77.212809
# Name: 46041, dtype: object
# 47456 District Name        latur
# Market Name        Nilanga
# lat              19.027994
# lon              72.836582
# Name: 47456, dtype: object
# 47951 District Name          amarawati
# Market Name      Chandur Railway
# lat                    17.128285
# lon                    78.459436
# Name: 47951, dtype: object
# 48284 District Name                                           ahmednagar
# Market Name      Om Chaitanya Multistate Agro Purpose CoOp Society
# lat                                                      11.657662
# lon                                                      92.731708
# Name: 48284, dtype: object
# 48396 District Name                 beed
# Market Name      Parali Vaijyanath
# lat                      18.906836
# lon                      75.674158
# Name: 48396, dtype: object
# 49005 District Name                    ahmednagar
# Market Name      Shree Sairaj Krushi Market
# lat                               20.391683
# lon                               77.215982
# Name: 49005, dtype: object
# 49748 District Name       sangli
# Market Name           Vita
# lat              19.363427
# lon              76.312049
# Name: 49748, dtype: object
# 50535 District Name                                               nashik
# Market Name      Shivsiddha Govind Producer Company Limited San...
# lat                                                      20.391683
# lon                                                      77.215982
# Name: 50535, dtype: object
# 56072 District Name     parbhani
# Market Name          Purna
# lat              18.906836
# lon              75.674158
# Name: 56072, dtype: object
# 56602 District Name     parbhani
# Market Name         Jintur
# lat              18.961953
# lon              72.832585
# Name: 56602, dtype: object
# 70091 District Name        akola
# Market Name           Akot
# lat              12.655489
# lon              77.212809
# Name: 70091, dtype: object
# 72147 District Name              ahmednagar
# Market Name      Shrigonda(Gogargaon)
# lat                         20.391683
# lon                         77.215982
# Name: 72147, dtype: object
# 79827 District Name         ahmednagar
# Market Name      Rahuri(Songaon)
# lat                     19.21482
# lon                    72.842627
# Name: 79827, dtype: object
# 93080 District Name       nanded
# Market Name          Umari
# lat              19.197312
# lon              72.946178
# Name: 93080, dtype: object
# 124166 District Name    aurangabad
# Market Name      Aurangabad
# lat               12.655489
# lon               77.212809
# Name: 124166, dtype: object
# 125958 District Name         jalgaon
# Market Name      Raver(Sauda)
# lat                  19.21482
# lon                 72.842627
# Name: 125958, dtype: object
# 127508 District Name    amarawati
# Market Name       Daryapur
# lat              28.660704
# lon              77.006429
# Name: 127508, dtype: object
# 135798 District Name     parbhani
# Market Name           Selu
# lat              20.391683
# lon              77.215982
# Name: 135798, dtype: object
# 158505 District Name                                                dhule
# Market Name      Janata Agri Market (DLS Agro Infrastructure Pv...
# lat                                                      18.961953
# lon                                                      72.832585
# Name: 158505, dtype: object
# 165932 District Name         beed
# Market Name        Vadvani
# lat              19.363427
# lon              76.312049
# Name: 165932, dtype: object
# 181688 District Name    ahmednagar
# Market Name          Karjat
# lat               17.456168
# lon               78.535967
# Name: 181688, dtype: object
# 203276 District Name    nandurbar
# Market Name         Taloda
# lat              19.405779
# lon               75.70204
# Name: 203276, dtype: object
# 204518 District Name                      hingoli
# Market Name      Sant Namdev Krushi Bazar,
# lat                              20.391683
# lon                              77.215982
# Name: 204518, dtype: object
# 212305 District Name                pune
# Market Name      Indapur(Bhigwan)
# lat                     18.733232
# lon                     79.331818
# Name: 212305, dtype: object
# 227853 District Name       nanded
# Market Name        Mudkhed
# lat              19.055997
# lon              72.922665
# Name: 227853, dtype: object
# 234056 District Name     parbhani
# Market Name           Bori
# lat              19.405779
# lon               75.70204
# Name: 234056, dtype: object
# 261917 District Name    amarawati
# Market Name          Varud
# lat              19.363427
# lon              76.312049
# Name: 261917, dtype: object
# 308224 District Name         pune
# Market Name           Nira
# lat              19.027994
# lon              72.836582
# Name: 308224, dtype: object
# 346305 District Name    chandrapur
# Market Name      Chandrapur
# lat               17.128285
# lon               78.459436
# Name: 346305, dtype: object
# 432413 District Name                          nashik
# Market Name      Premium Krushi Utpanna Bazar
# lat                                 18.906836
# lon                                 75.674158
# Name: 432413, dtype: object
# 657465 District Name       raigad
# Market Name        Alibagh
# lat              12.655489
# lon              77.212809
# Name: 657465, dtype: object
# 658000 District Name       raigad
# Market Name          Murud
# lat              19.055997
# lon              72.922665
# Name: 658000, dtype: object
# 658301 District Name       raigad
# Market Name        Mangaon
# lat              19.055997
# lon              72.922665
# Name: 658301, dtype: object
# 728667 District Name        thane
# Market Name       Bhivandi
# lat              19.405779
# lon               75.70204
# Name: 728667, dtype: object

# %%
sdf = pd.read_csv("semifinal.csv")
A = sdf.head()

# %%
A.to_csv('test.csv')

# %%
sem = pd.read_csv("semifinal.csv")
test = sem.head()
test.to_csv("test.csv")

# %%
models= dict()

# %%
import pandas as pd
import numpy as np

# --- Configuration ---
# Define the target commodity for this time series analysis.
TARGET_COMMODITY = 'Onion'
# Define the number of preceding weeks to use as features
LAG_WINDOW = 4 

def load_data(file_path):
    """Loads the CSV file into a DataFrame."""
    print(f"Loading data from {file_path}...")
    df = pd.read_csv(file_path, index_col=False)
    # Drop the first two unnamed/redundant index columns if they exist
    df = df.iloc[:, 2:]
    return df

def drop_redundant_columns(df):
    """
    Drops columns that are constant, near-constant, or provide redundant
    or non-numerical/non-essential information for this time series model.
    """
    columns_to_drop = [
        'STATE', 'Variety', 'Grade', 'id', 'city', 'std-code', 
        'state', 'gst-state-code', 'iso_3166-2', 'latitude_x', 
        'longitude_x', 'altitude', 'date', 'latitude_y', 'longitude_y', 
        'daylight_duration', 'sunshine_duration',
    ]
    columns_to_drop.extend(['population', 'rank'])
    
    columns_to_drop = list(set(columns_to_drop) & set(df.columns))
    if 'Market Name' in columns_to_drop:
        columns_to_drop.remove('Market Name')
        
    print(f"Dropping {len(columns_to_drop)} columns.")
    df_cleaned = df.drop(columns=columns_to_drop, errors='ignore')
    return df_cleaned

def preprocess_and_aggregate_weekly(df_cleaned, commodity=TARGET_COMMODITY):
    """
    Filters data, converts to datetime, and aggregates to weekly average.
    """
    df_filtered = df_cleaned[df_cleaned['Commodity'] == commodity].copy()
    print(f"\nFiltered data for commodity: {commodity}. Records: {len(df_filtered)}")
    
    if df_filtered.empty:
        print(f"No data found for {commodity}.")
        return None

    df_filtered['Price Date'] = pd.to_datetime(df_filtered['Price Date'])
    df_filtered = df_filtered.sort_values(by=['Market Name', 'Price Date'])
    df_filtered = df_filtered.drop(columns=['Commodity', 'District Name'], errors='ignore')

    # Aggregation Rules
    agg_rules = {
        'Min_Price': 'mean',
        'Max_Price': 'mean',
        'Modal_Price': 'mean',
        'temperature_2m_mean': 'mean',
        'temperature_2m_max': 'max',
        'temperature_2m_min': 'min',
        'wind_speed_10m_max': 'mean',
        'precipitation_sum': 'sum', 
        'precipitation_hours': 'sum',
        # We aggregate weather_code by Mode (most common weather that week)
        'weather_code': lambda x: x.mode()[0] if not x.empty else np.nan
    }
    agg_rules = {col: func for col, func in agg_rules.items() if col in df_filtered.columns}

    def resample_market(market_group):
        market_group = market_group.set_index('Price Date').sort_index()
        return market_group.resample('W').agg(agg_rules).fillna(method='ffill')

    df_weekly = df_filtered.groupby('Market Name').apply(resample_market)
    
    print(f"Data aggregated weekly for {commodity}.")
    return df_weekly

def create_lagged_features(df_weekly, lag_window=LAG_WINDOW):
    """
    Creates lagged features for weather columns and Modal_Price.
    UPDATED: Now includes weather_code as a direct numerical lag (no OHE).
    """
    print(f"\nCreating lagged features (Lag 1 up to Lag {lag_window})...")
    
    # Added 'weather_code' to this list to implement the lag
    features_to_lag = [
        'Modal_Price',
        'temperature_2m_mean', 
        'temperature_2m_max', 
        'temperature_2m_min', 
        'wind_speed_10m_max', 
        'precipitation_sum',
        'precipitation_hours',
        'weather_code'  # <-- NOW INCLUDED AS STANDARD LAG
    ]

    features_to_lag = [f for f in features_to_lag if f in df_weekly.columns]
    df_lagged = df_weekly.copy()
    
    for feature in features_to_lag:
        for lag in range(1, lag_window + 1):
            new_col_name = f'{feature}_Lag{lag}'
            df_lagged[new_col_name] = df_lagged.groupby(level=0)[feature].shift(lag)

    df_lagged = df_lagged.dropna()

    print(f"Finished creating lagged features. Final Shape: {df_lagged.shape}")
    print("Features include simple weather_code lags (e.g., weather_code_Lag1).")
    
    return df_lagged

if __name__ == "__main__":
    file_path = 'semifinal.csv' 
    df = load_data(file_path)
    df_cleaned = drop_redundant_columns(df)
    df_time_series = preprocess_and_aggregate_weekly(df_cleaned, commodity=TARGET_COMMODITY)

    if df_time_series is not None:
        df_final_features = create_lagged_features(df_time_series, lag_window=LAG_WINDOW)
        output_file = f'{TARGET_COMMODITY.lower()}_market_lagged_features.csv'
        df_final_features.to_csv(output_file)
        print(f"\n--- SUCCESS ---")
        print(f"Saved to: {output_file}")
        print("Please re-run model_training.py now.")
# Out:
# Loading data from semifinal.csv...
# Dropping 18 columns.
#
# Filtered data for commodity: Onion. Records: 24962
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_20184\2203275894.py:72: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return market_group.resample('W').agg(agg_rules).fillna(method='ffill')
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_20184\2203275894.py:74: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_weekly = df_filtered.groupby('Market Name').apply(resample_market)
# Data aggregated weekly for Onion.
#
# Creating lagged features (Lag 1 up to Lag 4)...
# Finished creating lagged features. Final Shape: (7973, 42)
# Features include simple weather_code lags (e.g., weather_code_Lag1).
#
# --- SUCCESS ---
# Saved to: onion_market_lagged_features.csv
# Please re-run model_training.py now.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.preprocessing import StandardScaler
import pickle 

# --- Configuration ---
INPUT_FILE = 'onion_market_lagged_features.csv'  # Make sure this matches your data prep output
TARGET_COLUMN = 'Modal_Price'
TEST_SPLIT_RATIO = 0.2 
N_SPLITS = 5 
COMMODITY_NAME = 'Onion'

# --- GPU Configuration ---
GPU_ENABLED_PARAMS = {
    'tree_method': 'hist', 
    'device': 'cuda'
}

def load_and_prepare_data(file_path):
    try:
        # Ensure we parse dates correctly
        df = pd.read_csv(file_path, index_col=[0, 1], parse_dates=True)
        print(f"Loaded data. Shape: {df.shape}")
    except FileNotFoundError:
        print(f"Error: {file_path} not found.")
        return None, None, None

    y = df[TARGET_COLUMN]
    # Drop current week targets so we don't cheat
    X = df.drop(columns=['Min_Price', 'Max_Price', TARGET_COLUMN], errors='ignore')
    return df, X, y

def split_and_scale_data(X, y):
    # Use time-based split, not random
    split_index = int(len(X) * (1 - TEST_SPLIT_RATIO))
    
    X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
    y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]

    print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
    
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)
    
    return X_train_scaled_df, X_test_scaled_df, y_train, y_test, scaler

def tune_model_with_tscv(X_train, y_train):
    print("\n--- Tuning Model (Conservative Mode) ---")

    # FIXED: Added regularization to prevent extreme price predictions
    param_grid = {
        'n_estimators': [300, 500],
        'max_depth': [3, 5],       # Lower depth = less overfitting to spikes
        'learning_rate': [0.01, 0.05],
        'subsample': [0.7, 0.8],
        'colsample_bytree': [0.7, 0.8],
        'reg_alpha': [0.1, 1.0],   # L1 Regularization (conservatism)
        'reg_lambda': [1.0, 2.0]   # L2 Regularization (conservatism)
    }

    xgb = XGBRegressor(
        objective='reg:squarederror', 
        random_state=42, 
        n_jobs=-1,
        **GPU_ENABLED_PARAMS
    )

    tscv = TimeSeriesSplit(n_splits=N_SPLITS)
    
    random_search = RandomizedSearchCV(
        estimator=xgb,
        param_distributions=param_grid,
        scoring='neg_mean_absolute_error', # Optimize for MAE (Dollar amount) not MSE
        cv=tscv,
        n_iter=15, 
        verbose=1,
        random_state=42,
        n_jobs=-1
    )

    random_search.fit(X_train, y_train)
    print(f"Best MAE params: {random_search.best_params_}")
    return random_search.best_estimator_

def final_evaluation(model, X_test, y_test):
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"\n--- Final Test Set Metrics ---")
    print(f"MAE: {mae:.2f}")
    print(f"R2: {r2:.4f}")
    
    # Check for bias
    avg_actual = np.mean(y_test)
    avg_pred = np.mean(y_pred)
    print(f"Avg Actual: {avg_actual:.2f} | Avg Predicted: {avg_pred:.2f}")
    if avg_pred > avg_actual * 1.1:
        print("WARNING: Model is systematically over-predicting.")

def save_model_artifacts(model, scaler):
    with open('Onion.pkl', 'wb') as file:
        pickle.dump(model, file)
    with open('scaler.pkl', 'wb') as file:
        pickle.dump(scaler, file)
    print("Artifacts saved.")

if __name__ == "__main__":
    df_data, X, y = load_and_prepare_data(INPUT_FILE)
    if X is not None:
        X_train, X_test, y_train, y_test, scaler = split_and_scale_data(X, y)
        best_xgb_model = tune_model_with_tscv(X_train, y_train)
        final_evaluation(best_xgb_model, X_test, y_test)
        save_model_artifacts(best_xgb_model, scaler,"Onion.pkl","o_scaler.pkl")
# Out:
# C:\Users\Atharv\AppData\Local\Temp\ipykernel_20184\802727568.py:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(file_path, index_col=[0, 1], parse_dates=True)
# Loaded data. Shape: (7973, 42)
# Train size: 6378, Test size: 1595
#
# --- Tuning Model (Conservative Mode) ---
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Best MAE params: {'subsample': 0.7, 'reg_lambda': 2.0, 'reg_alpha': 0.1, 'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# --- Final Test Set Metrics ---
# MAE: 201.30
# R2: 0.9326
# Avg Actual: 2333.72 | Avg Predicted: 2325.69
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 120
#     118 best_xgb_model = tune_model_with_tscv(X_train, y_train)
#     119 final_evaluation(best_xgb_model, X_test, y_test)
# --> 120 save_model_artifacts(best_xgb_model, scaler,"Onion.pkl","o_scaler.pkl")
#
# TypeError: save_model_artifacts() takes 2 positional arguments but 4 were given

# %%
save_model_artifacts(best_xgb_model, scaler)
# Out:
# Artifacts saved.
